# %% [markdown]
# # Add new Column to Dataframe

# %%
import pandas as pd

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
#   background-color:white;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
#   background-color:white;
# }
# </style>

# %%
nba = pd.read_csv('../nba.csv')
basketBall = pd.read_csv('../nba.csv')
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0

# %%
nba['Salary']
# nba['Company']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba['Company'] = 'Accenture'

# %%
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary    Company
# 0              Texas   7730337.0  Accenture
# 1          Marquette   6796117.0  Accenture
# 2  Boston University         NaN  Accenture
# 3      Georgia State   1148640.0  Accenture
# 4                NaN   5000000.0  Accenture
# 5                NaN  12000000.0  Accenture

# %%
nba['League'] = 'Baskterball Bundesliga'

# %%
nba.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary    Company                  League
# 448    Butler  15409570.0  Accenture  Baskterball Bundesliga
# 449      Duke   1348440.0  Accenture  Baskterball Bundesliga
# ...

# %%
basketBall.insert(loc=3,column='Sports',value='Basket Ball')
# Out:
#   File "<ipython-input-28-76a5eaaf4e3c>", line 1
#     basketBall.insert(index=3,'Sports','Basket Ball')
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
basketBall.head(5)
# Out:
#             Name            Team  Number       Sports Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basket Ball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basket Ball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basket Ball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basket Ball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basket Ball       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
basketBall.insert(4,'Country','Australia')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8e9b86a07905> in <module>
# ----> 1 basketBall.insert(4,'Country','Australia')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# ...

# %%
basketBall.head(10)
# Out:
#             Name            Team  Number       Sports    Country Position  \
# 0  Avery Bradley  Boston Celtics     0.0  Basket Ball  Australia       PG
# 1    Jae Crowder  Boston Celtics    99.0  Basket Ball  Australia       SF
# 2   John Holland  Boston Celtics    30.0  Basket Ball  Australia       SG
# 3    R.J. Hunter  Boston Celtics    28.0  Basket Ball  Australia       SG
# 4  Jonas Jerebko  Boston Celtics     8.0  Basket Ball  Australia       PF
# 5   Amir Johnson  Boston Celtics    90.0  Basket Ball  Australia       PF
# 6  Jordan Mickey  Boston Celtics    55.0  Basket Ball  Australia       PF
# 7   Kelly Olynyk  Boston Celtics    41.0  Basket Ball  Australia        C
# 8   Terry Rozier  Boston Celtics    12.0  Basket Ball  Australia       PG
# 9   Marcus Smart  Boston Celtics    36.0  Basket Ball  Australia       PG
#
#     Age Height  Weight            College      Salary
# 0  25.0    6-2   180.0              Texas   7730337.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1fb84834c5b8> in <module>
# ----> 1 basket
#
# NameError: name 'basket' is not defined
