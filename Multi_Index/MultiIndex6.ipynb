# %% [markdown]
# # Extract Rows from a MultiIndex Dataframe

# %%
import pandas as pd

# %%
# %%html
# <style>
#     table.dataframe th,table.dataframe td{
#         background-color:white;
#         border:1px solid black;
#     }
# </style>
# Out:
# <style>
#     table.dataframe th,table.dataframe td{
#         background-color:white;
#         border:1px solid black;
#     }
# </style>

# %%
bigmac = pd.read_csv('../bigmac.csv',parse_dates=['Date'],index_col=['Date','Country'])
bigmac.sort_index(inplace=True)
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.loc['2010-01-01']
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.loc['2010-01-01','Argentina']
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc['2010-01-01',"Price in US Dollars"] #price in US dollar is the original name of the column
# Out:
# Date        Country
# 2010-01-01  Argentina         1.84
#             Australia         3.98
#             Brazil            4.76
#             Britain           3.67
#             Canada            3.97
#             Chile             3.18
#             China             1.83
#             Colombia          3.91
#             Costa Rica        3.52
#             Czech Republic    3.71
#             Denmark           5.99
#             Egypt             2.38
#             Euro area         4.84
#             Hong Kong         1.91
#             Hungary           3.86
#             Indonesia         2.24
#             Israel            3.99
#             Japan             3.50
#             Latvia            3.09
#             Lithuania         2.87
#             Malaysia          2.08
#             Mexico            2.50
#             New Zealand       3.61
#             Norway            7.02
#             Pakistan          2.42
#             Peru              2.81
# ...

# %%
bigmac.loc[('2010-01-01','Argentina'),'Price in US Dollars']
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2016-01-01','India'),'Price in US Dollars']
# Out:
# Date        Country
# 2016-01-01  India      1.9
# Name: Price in US Dollars, dtype: float64

# %%
bigmac.loc[('2010-01-01',)]
# Out:
#                 Price in US Dollars
# Country
# Argentina                      1.84
# Australia                      3.98
# Brazil                         4.76
# Britain                        3.67
# Canada                         3.97
# Chile                          3.18
# China                          1.83
# Colombia                       3.91
# Costa Rica                     3.52
# Czech Republic                 3.71
# Denmark                        5.99
# Egypt                          2.38
# Euro area                      4.84
# Hong Kong                      1.91
# Hungary                        3.86
# Indonesia                      2.24
# Israel                         3.99
# Japan                          3.50
# Latvia                         3.09
# Lithuania                      2.87
# Malaysia                       2.08
# Mexico                         2.50
# New Zealand                    3.61
# Norway                         7.02
# Pakistan                       2.42
# ...

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.iloc[0]
bigmac.iloc[[10,20,132,12]]
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Denmark                   5.99
#            Malaysia                  2.08
# 2011-07-01 Sri Lanka                 2.56
# 2010-01-01 Euro area                 4.84
