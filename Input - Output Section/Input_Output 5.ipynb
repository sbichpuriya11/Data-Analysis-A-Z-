# %% [markdown]
# # Export excel File

# %%
import pandas as pd

# %%
baby_names = pd.read_csv('https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv')

# %%
baby_names.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
males = baby_names[baby_names['Gender']=='MALE']
males
# Out:
#        Year of Birth Gender                   Ethnicity Child's First Name  \
# 545             2011   MALE  ASIAN AND PACIFIC ISLANDER              AARAV
# 546             2011   MALE  ASIAN AND PACIFIC ISLANDER              AARON
# 547             2011   MALE  ASIAN AND PACIFIC ISLANDER              ABDUL
# 548             2011   MALE  ASIAN AND PACIFIC ISLANDER           ABDULLAH
# 549             2011   MALE  ASIAN AND PACIFIC ISLANDER               ADAM
# ...              ...    ...                         ...                ...
# 29455           2016   MALE          WHITE NON HISPANIC            Cheskel
# 29456           2015   MALE          WHITE NON HISPANIC             Arthur
# 29458           2015   MALE          WHITE NON HISPANIC               Joel
# 29461           2015   MALE          WHITE NON HISPANIC             Mendel
# 29462           2016   MALE  ASIAN AND PACIFIC ISLANDER              Isaac
#
#        Count  Rank
# 545       15    51
# 546       51    19
# ...

# %%
females = baby_names[baby_names['Gender']== 'FEMALE']
females
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 29454           2016  FEMALE            HISPANIC           Nathalie     11
# 29457           2015  FEMALE            HISPANIC            Joselyn     12
# 29459           2016  FEMALE            HISPANIC             Alayna     10
# 29460           2015  FEMALE            HISPANIC            Yaritza     12
# 29463           2015  FEMALE  WHITE NON HISPANIC            Alessia     12
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
excel_file = pd.ExcelWriter('Baby_Names.xlsx')

# %%
males.to_excel(excel_file,sheet_name='Boys',index=False)

# %%
females.to_excel(excel_file,sheet_name='Girls',index=False,columns=['Year of Birth','Gender','Ethnicity'])

# %%
excel_file.save()
