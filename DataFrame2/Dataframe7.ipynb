# %% [markdown]
# # The .between() Method

# %%
import pandas as pd

# %%
# %%HTML
# <style>
# table.dataframe th,table.dataframe td{
#     border:1px solid black;
#     background-color:white;
#     text-align:left;
# }
# </style>
# Out:
# <style>
# table.dataframe th,table.dataframe td{
#     border:1px solid black;
#     background-color:white;
#     text-align:left;
# }
# </style>

# %%
foods = pd.read_csv('../foods.csv')
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
foods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  1000 non-null   object
#  1   Gender      1000 non-null   object
#  2   City        1000 non-null   object
#  3   Frequency   1000 non-null   object
#  4   Item        1000 non-null   object
#  5   Spend       1000 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
foods['Item'] = foods['Item'].astype('category')
foods['Gender'] = foods['Gender'].astype('category')
foods['City'] = foods['City'].astype('category')
foods['Frequency'] = foods['Frequency'].astype('category')

# %%
foods.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
foods[foods['Spend'].between(10,20)]
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 7         Paul    Male  Philadelphia   Monthly    Chalupa  17.65
# 10      Samuel    Male      Stamford     Daily  Ice Cream  15.17
# ..         ...     ...           ...       ...        ...    ...
# 962     Brenda  Female      New York   Monthly    Burrito  16.36
# 970     Rachel  Female  Philadelphia    Seldom      Sushi  11.68
# 972      Wayne    Male      Stamford      Once  Ice Cream  14.13
# 979       Eric    Male      Stamford      Once     Burger  19.12
# 993       Mark    Male  Philadelphia    Seldom      Donut  13.79
#
# [113 rows x 6 columns]

# %%
item = foods['Item']=='Chalupa'
spend = foods['Spend'].between(10,30)

foods[item & spend]
# Out:
#     First Name  Gender          City Frequency     Item  Spend
# 1         Eric    Male      Stamford     Daily  Chalupa  10.56
# 4      Deborah  Female  Philadelphia     Daily  Chalupa  23.49
# 7         Paul    Male  Philadelphia   Monthly  Chalupa  17.65
# 24      Gerald    Male      New York    Yearly  Chalupa  29.90
# 53     Lillian  Female  Philadelphia     Never  Chalupa  18.63
# 111    Lillian  Female      New York    Seldom  Chalupa  17.05
# 158     Johnny    Male      New York   Monthly  Chalupa  28.56
# 244       Rose  Female  Philadelphia    Yearly  Chalupa  27.72
# 328      Henry    Male      New York     Daily  Chalupa  25.73
# 329    Brandon    Male      Stamford    Seldom  Chalupa  29.00
# 334  Katherine  Female  Philadelphia    Seldom  Chalupa  10.16
# 359       Mary  Female  Philadelphia    Seldom  Chalupa  24.97
# 383      Steve    Male      Stamford   Monthly  Chalupa  14.88
# 404       Carl    Male      Stamford    Seldom  Chalupa  14.44
# ...

# %%
df = pd.read_csv('../employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df[df['Start Date'].between('1991-1-1','1992-12-12')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 24        John    Male 1992-07-01 2020-11-26 22:08:00   97950   13.873
# 27       Scott     NaN 1991-07-11 2020-11-26 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2020-11-26 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2020-11-26 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2020-11-26 20:58:00   76189   18.988
# 131    Rebecca  Female 1992-07-10 2020-11-26 00:23:00   94231   17.517
# 146   Patricia  Female 1992-11-25 2020-11-26 02:24:00   95322    4.150
# 148    Patrick     NaN 1991-07-14 2020-11-26 02:24:00  124488   14.837
# 156     Howard    Male 1992-04-27 2020-11-26 01:10:00  105062    1.563
# 166        NaN  Female 1991-07-09 2020-11-26 18:52:00   42341    7.014
# 170      Irene  Female 1992-01-29 2020-11-26 11:36:00  133772   19.020
# 172       Sara  Female 1991-09-23 2020-11-26 18:17:00   97058    9.402
# ...

# %%
df[df['Last Login Time'].between('10:30 AM','12:00 PM')]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2          Maria  Female 1993-04-23 2020-11-26 11:17:00  130590   11.858
# 7            NaN  Female 2015-07-20 2020-11-26 10:43:00   45906   11.598
# 40       Michael    Male 2008-10-10 2020-11-26 11:25:00   99283    2.665
# 45         Roger    Male 1980-04-17 2020-11-26 11:32:00   88010   13.886
# 81   Christopher    Male 2008-03-30 2020-11-26 10:52:00   47369   14.822
# 114       Ashley  Female 2002-08-04 2020-11-26 11:00:00   58698    6.811
# 138       Ashley  Female 2006-05-25 2020-11-26 11:30:00  112238    6.030
# 143       Teresa     NaN 2016-01-28 2020-11-26 10:55:00  140013    8.689
# 162       Arthur    Male 1998-04-13 2020-11-26 11:28:00   89786   14.422
# 170        Irene  Female 1992-01-29 2020-11-26 11:36:00  133772   19.020
# 196       Steven    Male 1985-11-10 2020-11-26 10:53:00   62719   19.127
# 209        Emily  Female 2007-09-20 2020-11-26 11:25:00   89434   11.295
# ...
