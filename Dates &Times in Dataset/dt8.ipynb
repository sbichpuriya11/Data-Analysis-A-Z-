# %% [markdown]
# # Create Range of dates with the pd.date_range() Method, Part 3

# %%
import pandas as pd

# %%
pd.date_range(end='2019-09-01',periods=23,freq='D')
# Out:
# DatetimeIndex(['2019-08-10', '2019-08-11', '2019-08-12', '2019-08-13',
#                '2019-08-14', '2019-08-15', '2019-08-16', '2019-08-17',
#                '2019-08-18', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23', '2019-08-24', '2019-08-25',
#                '2019-08-26', '2019-08-27', '2019-08-28', '2019-08-29',
#                '2019-08-30', '2019-08-31', '2019-09-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='B')
# Out:
# DatetimeIndex(['2019-07-31', '2019-08-01', '2019-08-02', '2019-08-05',
#                '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09',
#                '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15',
#                '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21',
#                '2019-08-22', '2019-08-23', '2019-08-26', '2019-08-27',
#                '2019-08-28', '2019-08-29', '2019-08-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='3D')
# Out:
# DatetimeIndex(['2019-06-27', '2019-06-30', '2019-07-03', '2019-07-06',
#                '2019-07-09', '2019-07-12', '2019-07-15', '2019-07-18',
#                '2019-07-21', '2019-07-24', '2019-07-27', '2019-07-30',
#                '2019-08-02', '2019-08-05', '2019-08-08', '2019-08-11',
#                '2019-08-14', '2019-08-17', '2019-08-20', '2019-08-23',
#                '2019-08-26', '2019-08-29', '2019-09-01'],
#               dtype='datetime64[ns]', freq='3D')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='W-SUN')
# Out:
# DatetimeIndex(['2019-03-31', '2019-04-07', '2019-04-14', '2019-04-21',
#                '2019-04-28', '2019-05-05', '2019-05-12', '2019-05-19',
#                '2019-05-26', '2019-06-02', '2019-06-09', '2019-06-16',
#                '2019-06-23', '2019-06-30', '2019-07-07', '2019-07-14',
#                '2019-07-21', '2019-07-28', '2019-08-04', '2019-08-11',
#                '2019-08-18', '2019-08-25', '2019-09-01'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='W-FRI')
# Out:
# DatetimeIndex(['2019-03-29', '2019-04-05', '2019-04-12', '2019-04-19',
#                '2019-04-26', '2019-05-03', '2019-05-10', '2019-05-17',
#                '2019-05-24', '2019-05-31', '2019-06-07', '2019-06-14',
#                '2019-06-21', '2019-06-28', '2019-07-05', '2019-07-12',
#                '2019-07-19', '2019-07-26', '2019-08-02', '2019-08-09',
#                '2019-08-16', '2019-08-23', '2019-08-30'],
#               dtype='datetime64[ns]', freq='W-FRI')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='M')
# Out:
# DatetimeIndex(['2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
#                '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#                '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30',
#                '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31',
#                '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31',
#                '2019-06-30', '2019-07-31', '2019-08-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='SM')
# Out:
# DatetimeIndex(['2018-09-30', '2018-10-15', '2018-10-31', '2018-11-15',
#                '2018-11-30', '2018-12-15', '2018-12-31', '2019-01-15',
#                '2019-01-31', '2019-02-15', '2019-02-28', '2019-03-15',
#                '2019-03-31', '2019-04-15', '2019-04-30', '2019-05-15',
#                '2019-05-31', '2019-06-15', '2019-06-30', '2019-07-15',
#                '2019-07-31', '2019-08-15', '2019-08-31'],
#               dtype='datetime64[ns]', freq='SM-15')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='MS')
# Out:
# DatetimeIndex(['2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01',
#                '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01',
#                '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01',
#                '2019-07-01', '2019-08-01', '2019-09-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='Y')
# Out:
# DatetimeIndex(['1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
#                '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#                '2016-12-31', '2017-12-31', '2018-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(end='2019-09-01',periods=23,freq='3Y')
# Out:
# DatetimeIndex(['1952-12-31', '1955-12-31', '1958-12-31', '1961-12-31',
#                '1964-12-31', '1967-12-31', '1970-12-31', '1973-12-31',
#                '1976-12-31', '1979-12-31', '1982-12-31', '1985-12-31',
#                '1988-12-31', '1991-12-31', '1994-12-31', '1997-12-31',
#                '2000-12-31', '2003-12-31', '2006-12-31', '2009-12-31',
#                '2012-12-31', '2015-12-31', '2018-12-31'],
#               dtype='datetime64[ns]', freq='3A-DEC')

# %%
pd.date_range(end='2019-09-01',periods=30,freq='10H')
# Out:
# DatetimeIndex(['2019-08-19 22:00:00', '2019-08-20 08:00:00',
#                '2019-08-20 18:00:00', '2019-08-21 04:00:00',
#                '2019-08-21 14:00:00', '2019-08-22 00:00:00',
#                '2019-08-22 10:00:00', '2019-08-22 20:00:00',
#                '2019-08-23 06:00:00', '2019-08-23 16:00:00',
#                '2019-08-24 02:00:00', '2019-08-24 12:00:00',
#                '2019-08-24 22:00:00', '2019-08-25 08:00:00',
#                '2019-08-25 18:00:00', '2019-08-26 04:00:00',
#                '2019-08-26 14:00:00', '2019-08-27 00:00:00',
#                '2019-08-27 10:00:00', '2019-08-27 20:00:00',
#                '2019-08-28 06:00:00', '2019-08-28 16:00:00',
#                '2019-08-29 02:00:00', '2019-08-29 12:00:00',
#                '2019-08-29 22:00:00', '2019-08-30 08:00:00',
#                '2019-08-30 18:00:00', '2019-08-31 04:00:00',
#                '2019-08-31 14:00:00', '2019-09-01 00:00:00'],
#               dtype='datetime64[ns]', freq='10H')

# %%
pd.date_range(end='2019-09-01',periods=30,freq='10M')
# Out:
# DatetimeIndex(['1995-06-30', '1996-04-30', '1997-02-28', '1997-12-31',
#                '1998-10-31', '1999-08-31', '2000-06-30', '2001-04-30',
#                '2002-02-28', '2002-12-31', '2003-10-31', '2004-08-31',
#                '2005-06-30', '2006-04-30', '2007-02-28', '2007-12-31',
#                '2008-10-31', '2009-08-31', '2010-06-30', '2011-04-30',
#                '2012-02-29', '2012-12-31', '2013-10-31', '2014-08-31',
#                '2015-06-30', '2016-04-30', '2017-02-28', '2017-12-31',
#                '2018-10-31', '2019-08-31'],
#               dtype='datetime64[ns]', freq='10M')
